# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
# Out:
# /tmp/ipykernel_30546/2346321470.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv('./data/stock_TSCO.csv')

# %%
df.head()
# Out:
#          Date   Open   High    Low  Close  Adjusted Close    Volume  \
# 0  2024-03-15  286.3  288.9  285.3  287.6           287.6  28730980
# 1  2024-03-14  286.7  287.6  285.1  286.1           286.1  11658370
# 2  2024-03-13  286.4  286.6  283.6  286.0           286.0  17848961
# 3  2024-03-12  284.0  286.0  282.8  285.8           285.8  24801539
# 4  2024-03-11  285.1  286.6  282.2  282.2           282.2  33775449
#
#    Dividend Amount  Split Coefficient
# 0              0.0                1.0
# 1              0.0                1.0
# 2              0.0                1.0
# 3              0.0                1.0
# 4              0.0                1.0

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['Date'][:100], df['Close'][:100], label='Close Price history')
plt.title('Close Price History')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.show()
