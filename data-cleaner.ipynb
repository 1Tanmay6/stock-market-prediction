# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
stock_data = pd.read_csv('./data/stock_TSCO.csv')
stock_data.head()
# Out:
#          Date   Open   High    Low  Close  Adjusted Close    Volume  \
# 0  2024-03-15  286.3  288.9  285.3  287.6           287.6  28730980
# 1  2024-03-14  286.7  287.6  285.1  286.1           286.1  11658370
# 2  2024-03-13  286.4  286.6  283.6  286.0           286.0  17848961
# 3  2024-03-12  284.0  286.0  282.8  285.8           285.8  24801539
# 4  2024-03-11  285.1  286.6  282.2  282.2           282.2  33775449
#
#    Dividend Amount  Split Coefficient
# 0              0.0                1.0
# 1              0.0                1.0
# 2              0.0                1.0
# 3              0.0                1.0
# 4              0.0                1.0

# %%
stock_data.isnull().sum()
# Out:
# Date                 0
# Open                 0
# High                 0
# Low                  0
# Close                0
# Adjusted Close       0
# Volume               0
# Dividend Amount      0
# Split Coefficient    0
# dtype: int64

# %%
sns.displot(stock_data['Volume'], kde=True, bins=30)

# %%
stock_data['Date'] = pd.to_datetime(stock_data['Date'])

# %%
stock_data.head(5)
# Out:
#         Date   Open   High    Low  Close  Adjusted Close    Volume  \
# 0 2024-03-15  286.3  288.9  285.3  287.6           287.6  28730980
# 1 2024-03-14  286.7  287.6  285.1  286.1           286.1  11658370
# 2 2024-03-13  286.4  286.6  283.6  286.0           286.0  17848961
# 3 2024-03-12  284.0  286.0  282.8  285.8           285.8  24801539
# 4 2024-03-11  285.1  286.6  282.2  282.2           282.2  33775449
#
#    Dividend Amount  Split Coefficient
# 0              0.0                1.0
# 1              0.0                1.0
# 2              0.0                1.0
# 3              0.0                1.0
# 4              0.0                1.0

# %%
sns.lineplot(x=stock_data['Date'], y=stock_data['Volume'], )
# Out:
# <Axes: xlabel='Date', ylabel='Volume'>
